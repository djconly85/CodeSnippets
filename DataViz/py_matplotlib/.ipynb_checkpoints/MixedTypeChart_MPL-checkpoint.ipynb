# %%
import matplotlib.pyplot as plt

xvals = ['a','b','c']
barseries1 = [1,3,6]
lineseries = [i * 1.302 for i in barseries1]

plt.plot(xvals, lineseries)
plt.bar(xvals, barseries1)
# Out:
# <BarContainer object of 3 artists>

# %%
import pandas as pd

in_csv = r'/Users/darrenconly/PythonProjects/CodeSnippets/DataViz/sample_data_csvs/DRAFT_defCorridor_metrics.csv'

df = pd.read_csv(in_csv)


dfp1 = df.loc[(df['proj_inum'] == 1) & (df['measure'] == 'havg_spd_worst4hrs') 
             & (df['data_year'] == 2016)]

dfp1.head(8)

ax = dfp1.plot()

dir(ax)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_autotitlepos',
#  '_axes',
#  '_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_clipon',
#  '_clippath',
#  '_connected',
#  '_contains',
#  '_convert_dx',
#  '_current_image',
#  '_facecolor',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
#  '_gen_axes_spines',
#  '_get_axis_list',
#  '_get_clipping_extent_bbox',
#  '_get_lines',
#  '_get_patches_for_fill',
#  '_get_view',
# ...
